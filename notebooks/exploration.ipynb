# %%
import sys
from pathlib import Path

# Add src to path
sys.path.insert(0, str(Path().resolve().parent))

import numpy as np
import pandas as pd
import plotly.io as pio
pio.renderers.default = 'notebook'
import ipywidgets as widgets
from IPython.display import display

# Import pipeline modules
from src.pipeline import process_file, process_new_files, load_processed_data
from src.config import DEFAULT_CSV_PATH, DEFAULT_EXCEL_PATH

# %% [markdown]
# # Finance Transaction Analysis
#
# This notebook uses the modular pipeline for data processing. You can still do interactive exploration here!

# %%
# Option 1: Process a specific CSV file
file_path = '/Users/juhorissanen/Desktop/Transactions.csv'
df = process_file(file_path, start_date='2025-01-01', save_excel=True)

# Option 2: Auto-detect and process new files
# df = process_new_files(save_excel=True)

# Option 3: Load already processed data from Excel
# df = load_processed_data()

print("Datan Alku:", df['date'].min())
print("Datan Loppu:", df['date'].max())
print(f"Total rows: {len(df)}")

# %% [markdown]
# ## Data Overview

# %%
# Display the dataframe
df.head()

# %%
# Check categories
print("Categories:")
print(df['category'].unique())
print("\n2nd Categories:")
print(df['2nd category'].unique())

# %% [markdown]
# ## Custom Analysis
#
# Add your custom analysis cells below. The pipeline handles all the data cleaning and categorization, so you can focus on analysis!
